# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.9-cp38-cp38-win_amd64.whl (1.2 MB)
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.9

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (3.5)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: regex in c:\programdata\anaconda3\lib\site-packages (from nltk) (2020.6.8)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk) (4.47.0)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk) (0.16.0)

# %%
import psycopg2
import re
import pandas as pd
from sqlalchemy import create_engine

import matplotlib.dates as mdates
import matplotlib.pyplot as plt

from wordcloud import WordCloud
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
#nltk.download('stopwords')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Parâmetros de conexão ao banco de dados
db_params = {
    "host": "localhost",
    "database": "telegram2",
    "user": "postgres",
    "password": "Reve1945"
}

url_pattern = r'(https?://\S+)'

built_df = pd.DataFrame()
lengths = []

# %%
try:
    # Conectando ao banco de dados
    conn = psycopg2.connect(**db_params)

    # Criando um cursor
    cursor = conn.cursor()

    # Exemplo de consulta SQL com paginação
    page_size = 100000  # Defina o tamanho da página desejado
    offset = 0

    total_messages_captured = 0  # Variável para contagem de mensagens capturadas

    while True:
        cursor.execute("SELECT * FROM messages_filtered_by_context_window_by_time_v6 LIMIT %s OFFSET %s", (page_size, offset))
        results = cursor.fetchall()

        if not results:
            break

        # Crie uma lista para armazenar as linhas capturadas na página atual
        new_rows = []

        for row in results:
            new_rows.append([row[0], row[1], row[2]])


        # Atualize a contagem de mensagens capturadas
        total_messages_captured += len(new_rows)
        print(f"Número de mensagens capturadas: {total_messages_captured}")

        # Crie um DataFrame a partir da lista de linhas da página atual
        df = pd.DataFrame(new_rows, columns = ["channel_id", "message_data", "message_utc"])
        # Remova as duplicatas do DataFrame, se necessário
        df = df.drop_duplicates()
        
        built_df = pd.concat([built_df, df], axis = 0)
        
        offset += page_size

    print("\n")
    print('Fim da construção do dataframe.')

    # Fechando o cursor
    cursor.close()

    # Fechando a conexão
    conn.close()

except (Exception, psycopg2.Error) as error:
    print("Erro na construção do dataframe:", error)

# %%
built_df = df.drop_duplicates()

built_df.head()

# %%
built_df.to_csv('dataset.csv', index = False)

# %%
# Crie um DataFrame a partir da lista de comprimentos
lengths_df = pd.DataFrame(lengths, columns = ['message_length'])

# Calcule o comprimento médio das mensagens
average_length = lengths_df['message_length'].mean()

# Exiba o comprimento médio
print(f"Comprimento médio das mensagens: {average_length:.2f} caracteres")

# Visualize a distribuição dos comprimentos das mensagens
plt.figure(figsize = (10, 6))
plt.hist(lengths, bins = 30, color = 'skyblue', edgecolor = 'black')
plt.title('Distribuição do Comprimento das Mensagens')
plt.xlabel('Comprimento da Mensagem (caracteres)')
plt.ylabel('Número de Mensagens')
plt.show()
# Out:
# Comprimento médio das mensagens: 267.44 caracteres

# %%
plt.figure(figsize = (12, 6))
plt.plot(built_df['message_utc'], built_df['message_data'].apply(len), label = 'Comprimento da Mensagem')
plt.title('Análise Temporal do Comprimento das Mensagens')
plt.xlabel('Timestamp')
plt.ylabel('Comprimento da Mensagem (caracteres)')
plt.legend()
plt.grid(True, linestyle = '--', alpha = 0.7)
plt.tight_layout()
plt.gca()
plt.show()

# %%
stopwords_list = [
    "de","a",  "o",  "que",
    "e",  "do", "da", "em",
    "um", "para",        "com","não",
    "uma","os", "no", "se",
    "na", "por","mais",        "as",
    "dos","como",        "mas","ao",
    "ele","das","à",  "seu",
    "sua","ou", "quando",      "muito",
    "nos","já", "eu", "também",
    "só", "pelo",        "pela",        "até",
    "isso",        "ela","entre",       "depois",
    "sem","mesmo",       "aos","seus",
    "quem",        "nas","me", "esse",
    "eles",        "você",        "essa",        "num",
    "nem","suas",        "meu","às",
    "minha",       "numa",        "pelos",       "elas",
    "qual",        "nós","lhe","deles",
    "essas",       "esses",       "pelas",       "este",
    "dele",        "tu", "te", "vocês",
    "vos","lhes",        "meus",        "minhas",
    "teu","tua","teus",        "tuas",
    "nosso",       "nossa",       "nossos",      "nossas",
    "dela",        "delas",       "esta",        "estes",
    "estas",       "aquele",      "aquela",      "aqueles",
    "aquelas",     "isto",        "aquilo",      "estou",
    "está",        "estamos",     "estão",       "estive",
    "esteve",      "estivemos",   "estiveram",   "estava",
    "estávamos",   "estavam",     "estivera",    "estivéramos",
    "esteja",      "estejamos",   "estejam",     "estivesse",
    "estivéssemos","estivessem",  "estiver",     "estivermos",
    "estiverem",   "hei","há", "havemos",
    "hão","houve",       "houvemos",    "houveram",
    "houvera",     "houvéramos",  "haja",        "hajamos",
    "hajam",       "houvesse",    "houvéssemos", "houvessem",
    "houver",      "houvermos",   "houverem",    "houverei",
    "houverá",     "houveremos",  "houverão",    "houveria",
    "houveríamos", "houveriam",   "sou","somos",
    "são","era","éramos",      "eram",
    "fui","foi","fomos",       "foram",
    "fora",        "fôramos",     "seja",        "sejamos",
    "sejam",       "fosse",       "fôssemos",    "fossem",
    "for","formos",      "forem",       "serei",
    "será",        "seremos",     "serão",       "seria",
    "seríamos",    "seriam",      "tenho",       "tem",
    "temos",       "tém","tinha",       "tínhamos",
    "tinham",      "tive",        "teve",        "tivemos",
    "tiveram",     "tivera",      "tivéramos",   "tenha",
    "tenhamos",    "tenham",      "tivesse",     "tivéssemos",
    "tivessem",    "tiver",       "tivermos",    "tiverem",
    "terei",       "terá",        "teremos",     "terão",
    "teria",       "teríamos",    "teriam", "pra",
    "fala", "disse", "diz", "vai"
]

# %%
if not built_df.empty:
    # Concatenar todas as mensagens em uma única string
    non_null_messages = built_df['message_data'].dropna()
    all_messages = ' '.join(non_null_messages)

    # Criar a nuvem de palavras
    wordcloud = WordCloud(stopwords = stopwords_list, 
                            normalize_plurals = False, 
                            width = 800, 
                            height = 400, 
                            background_color = 'white',
                            min_font_size = 25,
                            max_words = 15).generate(all_messages)

    # Exibir a nuvem de palavras usando Matplotlib
    plt.figure(figsize = (10, 5))
    plt.imshow(wordcloud, interpolation = 'bilinear')
    plt.axis('off')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-c28cbe50f1c0> in <module>
#       5
#       6     # Criar a nuvem de palavras
# ----> 7     wordcloud = WordCloud(stopwords = stopwords_list,
#       8                             width = 800,
#       9                             height = 400,
#
# C:\ProgramData\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     637             raise ValueError("WordCloud has not been calculated, call generate"
#     638                              " first.")
# --> 639
#     640     def to_image(self):
#     641         self._check_generated()
#
# C:\ProgramData\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     619
#     620         The input "text" is expected to be a natural text. If you pass a sorted
# --> 621         list of words, words will appear in your output twice. To remove this
#     622         duplication, set ``collocations=False``.
#     623
#
# C:\ProgramData\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     451                     font_size = int(2 * sizes[0] * sizes[1]
#     452                                     / (sizes[0] + sizes[1]))
# --> 453                 # quick fix for if self.layout_ contains less than 2 values
#     454                 # on very small images it can be empty
#     455                 except IndexError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     506                 if result is not None or font_size < self.min_font_size:
#     507                     # either we found a place or font-size went too small
# --> 508                     break
#     509                 # if we didn't find a place, make font smaller
#     510                 # but first try to rotate!
#
# AttributeError: 'ImageDraw' object has no attribute 'textbbox'

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\agabr\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
# Verificar se o DataFrame não está vazio e se a coluna 'message_data' está presente
if not built_df.empty and 'message_data' in built_df.columns:
    # Concatenar mensagens e converter para texto minúsculo
    all_messages = ' '.join(built_df['message_data'].dropna().astype(str).str.lower())

    # Tokenizar as palavras
    words = word_tokenize(all_messages)

    # Remover stopwords
    stop_words = set(stopwords.words('portuguese'))
    words = [word for word in words if word.isalnum() and word not in stop_words]

    # Calcular a frequência das palavras
    freq_dist = FreqDist(words)

    # Exibir as 15 palavras mais frequentes em um gráfico de barras
    plt.figure(figsize=(12, 6))
    freq_dist.plot(15, cumulative=False)
    plt.title('15 Palavras Mais Frequentes')
    plt.xlabel('Palavra')
    plt.ylabel('Frequência')
    plt.show()
